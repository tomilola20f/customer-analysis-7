# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0047-F845
#
#  Directory of C:\Users\tomil\lab-customer-analysis-round-7
#
# 09/01/2023  23:27    <DIR>          .
# 07/01/2023  11:17    <DIR>          ..
# 22/08/2022  15:06    <DIR>          .github
# 01/09/2022  09:38    <DIR>          .ipynb_checkpoints
# 22/08/2022  15:06    <DIR>          files_for_lab
# 09/01/2023  23:27         1,436,325 FINAL LAB ASSIGNMENT.ipynb
# 22/08/2022  15:06             1,157 readme.md
#                2 File(s)      1,437,482 bytes
#                5 Dir(s)  409,648,947,200 bytes free

# %%
cd files_for_lab
# Out:
# C:\Users\tomil\lab-customer-analysis-round-7\files_for_lab

# %%
df = pd.read_csv('csv_files/marketing_customer_analysis.csv')

# %%
df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
df.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'response', 'coverage',
#        'education', 'effective to date', 'employmentstatus', 'gender',
#        'income', 'location code', 'marital status', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies', 'policy type',
#        'policy', 'renew offer type', 'sales channel', 'total claim amount',
#        'vehicle class', 'vehicle size'],
#       dtype='object')

# %%
df._get_numeric_data().columns
# Out:
# Index(['customer lifetime value', 'income', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies',
#        'total claim amount'],
#       dtype='object')

# %%
num_cols = df._get_numeric_data().columns
cols = df.columns
list(set(cols) - set(num_cols))
# Out:
# ['customer',
#  'response',
#  'vehicle size',
#  'policy type',
#  'renew offer type',
#  'policy',
#  'sales channel',
#  'gender',
#  'education',
#  'marital status',
#  'effective to date',
#  'vehicle class',
#  'employmentstatus',
#  'location code',
#  'state',
#  'coverage']

# %%
# checking for NaN Values

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# customer                         0
# state                            0
# vehicle class                    0
# total claim amount               0
# sales channel                    0
# renew offer type                 0
# policy                           0
# policy type                      0
# number of policies               0
# number of open complaints        0
# months since policy inception    0
# months since last claim          0
# monthly premium auto             0
# marital status                   0
# location code                    0
# income                           0
# gender                           0
# employmentstatus                 0
# effective to date                0
# education                        0
# coverage                         0
# response                         0
# customer lifetime value          0
# vehicle size                     0
# dtype: int64

# %%
df
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective to date employmentstatus gender  income  ...  \
# ...

# %%
# getting the categorical features

# %%
categoricals = df.select_dtypes(np.object)
categoricals
# Out:
# C:\Users\tomil\AppData\Local\Temp\ipykernel_63228\983254351.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categoricals = df.select_dtypes(np.object)
#      customer       state response  coverage education effective to date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# ...

# %%
# getting the Numerical categorical

# %%
numericals = df.select_dtypes(include= np.number)
numericals
# Out:
#       customer lifetime value  income  monthly premium auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months since last claim  months since policy inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
sns.displot('customer lifetime Value')

# %%
sns.displot('income')

# %%
sns.displot('monthly premium auto')

# %%
sns.displot('months since last claim')

# %%
sns.displot('months since policz inception')

# %%
sns.displot('total claim amount')

# %%
sns.distplot(numericals)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.pairplot(numericals)

# %%
df_corr = df.corr() 
df_corr
# Out:
#                          customer lifetime value    income  \
# customer lifetime value                 1.000000  0.053040
# income                                  0.053040  1.000000
# monthly premium auto                    0.413803  0.004185
# number of policies                      0.300208 -0.005935
# total claim amount                      0.150272 -0.386132
#
#                          monthly premium auto  number of policies  \
# customer lifetime value              0.413803            0.300208
# income                               0.004185           -0.005935
# monthly premium auto                 1.000000           -0.017039
# number of policies                  -0.017039            1.000000
# total claim amount                   0.442015           -0.012563
#
#                          total claim amount
# customer lifetime value            0.150272
# income                            -0.386132
# monthly premium auto               0.442015
# ...

# %% [markdown]
# # processing data

# %%
import matplotlib.pyplot as plt
plt.figure()
df.hist()
plt.show()

# %%
#Reducing the effects of outliers using log_scale:
sns.displot(data=numericals,x="customer lifetime value",kind="hist",aspect=1.4,log_scale=10, bins=20)

# %%
fig, axs = plt.subplots(4, 2, figsize=(12, 10))
sns.histplot((numericals['customer lifetime value']),color='red',bins=40,ax=axs[0, 0])
sns.histplot((numericals['income']),color='blue',bins=40, ax=axs[0, 1])
sns.histplot((numericals['monthly premium auto']),color="green",bins=40,ax=axs[1, 0])
sns.histplot((numericals['months since last claim']),color="yellow",bins=40, ax=axs[1, 1])
sns.histplot((numericals['months since policy inception']),color='purple',bins=40, ax=axs[2, 0])
sns.histplot((numericals['number of policies']),color='black',bins=40, ax=axs[2,1 ])
sns.histplot((numericals['number of open complaints']),color='orange',bins=40,ax=axs[3, 0])
sns.histplot((numericals['total claim amount']),color='brown',bins=40, ax=axs[3, 1])
# Out:
# <AxesSubplot:xlabel='total claim amount', ylabel='Count'>

# %%
sns.displot(numericals, bins=20)

# %%
##Using Matplotlib to construct histograms
numericals.hist(figsize=(10,15),bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'customer lifetime value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly premium auto'}>],
#        [<AxesSubplot:title={'center':'months since last claim'}>,
#         <AxesSubplot:title={'center':'months since policy inception'}>,
#         <AxesSubplot:title={'center':'number of open complaints'}>],
#        [<AxesSubplot:title={'center':'number of policies'}>,
#         <AxesSubplot:title={'center':'total claim amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
#Removing the 'number of policies' column graph, dont want to loose too much data
new_graph=numericals.drop(['number of policies'], axis = 1)
new_graph.hist(figsize=(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'customer lifetime value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly premium auto'}>],
#        [<AxesSubplot:title={'center':'months since last claim'}>,
#         <AxesSubplot:title={'center':'months since policy inception'}>,
#         <AxesSubplot:title={'center':'number of open complaints'}>],
#        [<AxesSubplot:title={'center':'total claim amount'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
from scipy import stats 

numericals = df[df.select_dtypes(include=np.number).columns]
numericals

from scipy import stats 


for col in numericals.columns:
    
    
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    df = df[~((df[col] < (Q1 - 1.5 * IQR)) |(df[col] > (Q3 + 1.5 * IQR)))]
    columns_to_drop = ['number of policies']

# %%
df
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# 5     OC83172      Oregon              8256.297800      Yes     Basic
# ...       ...         ...                      ...      ...       ...
# 9127  TF56202  California              5032.165498       No     Basic
# 9128  YM19146  California              4100.398533       No   Premium
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective to date employmentstatus gender  income  ...  \
# ...

# %%
#checking the multicollinearity between the features
numericals.corr()
# Out:
#                                customer lifetime value    income  \
# customer lifetime value                       1.000000  0.053040
# income                                        0.053040  1.000000
# monthly premium auto                          0.413803  0.004185
# months since last claim                      -0.028267 -0.037378
# months since policy inception                -0.005292  0.013119
# number of open complaints                          NaN       NaN
# number of policies                            0.300208 -0.005935
# total claim amount                            0.150272 -0.386132
#
#                                monthly premium auto  months since last claim  \
# customer lifetime value                    0.413803                -0.028267
# income                                     0.004185                -0.037378
# monthly premium auto                       1.000000                -0.023371
# ...

# %%
##Showing a plot of the total number of responses
total_responses=categoricals['response'].value_counts()
total_responses
# Out:
# No     7826
# Yes    1308
# Name: response, dtype: int64

# %%
#Plot the Correlation Heatmap
corr = df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
df
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# 5     OC83172      Oregon              8256.297800      Yes     Basic
# ...       ...         ...                      ...      ...       ...
# 9127  TF56202  California              5032.165498       No     Basic
# 9128  YM19146  California              4100.398533       No   Premium
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective to date employmentstatus gender  income  ...  \
# ...

# %%
y_col = 'total claim amount'
x = pd.DataFrame(df[y_col]) #explanatory variable
y = df[df.columns.drop(y_col)]

# %%
df["total claim amount"].unique()
# Out:
# array([384.811147, 566.472247, 529.881344, ..., 185.530076, 322.575677,
#        541.282007])

# %%
df.columns
# Out:
# Index(['customer', 'customer lifetime value', 'response', 'coverage',
#        'effective to date', 'employmentstatus', 'gender', 'income',
#        'location code', 'marital status', 'monthly premium auto',
#        'number of policies', 'policy type', 'renew offer type',
#        'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
# splitting of x and y

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)
x_train
# Out:
#       total claim amount
# 3880          663.423782
# 2737          239.964694
# 2407          283.787384
# 1152          511.200000
# 5624          242.807725
# ...                  ...
# 6056          333.189774
# 8300          412.800000
# 8346          421.824276
# 8601          439.701118
# 1391          379.200000
#
# [4302 rows x 1 columns]

# %%
x_train
# Out:
#       total claim amount
# 3880          663.423782
# 2737          239.964694
# 2407          283.787384
# 1152          511.200000
# 5624          242.807725
# ...                  ...
# 6056          333.189774
# 8300          412.800000
# 8346          421.824276
# 8601          439.701118
# 1391          379.200000
#
# [4302 rows x 1 columns]

# %%
x_test
# Out:
#       total claim amount
# 984           284.000172
# 8848           32.714226
# 7425          734.400000
# 7516          292.800000
# 3959          436.800000
# ...                  ...
# 883           297.600000
# 1399          416.365369
# 6959          104.209216
# 2219          109.814874
# 6564          556.800000
#
# [1435 rows x 1 columns]

# %%
y_train
# Out:
#      customer  customer lifetime value response  coverage effective to date  \
# 3880  LR97507              2562.843896       No     Basic           2/19/11
# 2737  GX22886              3199.824902       No  Extended           1/25/11
# 2407  ON30714              4932.878744       No     Basic            2/6/11
# 1152  DQ28641              2665.222511       No     Basic            1/9/11
# 5624  FE46445              6965.423975       No  Extended           1/22/11
# ...       ...                      ...      ...       ...               ...
# 6056  YS71471              2685.738737       No     Basic            1/3/11
# 8300  XI36396              3151.162130       No  Extended           1/18/11
# 8346  SG82836              6439.779016       No  Extended           1/14/11
# 8601  QZ34525              6993.380588       No     Basic           2/21/11
# 1391  MZ24175              3096.511217      Yes  Extended           2/12/11
#
# ...

# %%
y_train = y_train.drop('customer', axis =1)          # drop customer column
y_train = y_train.drop('effective to date', axis= 1)

# %% [raw]
# y_test

# %%
print("Nb of rows of X_train = {}".format(len(x_train)))
print("Nb of rows of X_test = {}".format(len(x_test)))
print("Nb of rows of = {}".format(len(y_train)))
print("Nb of rows of y_test = {}".format(len(y_test)))
# Out:
# Nb of rows of X_train = 4302
# Nb of rows of X_test = 1435
# Nb of rows of = 4302
# Nb of rows of y_test = 1435

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test =  sc_x.transform(x_test)#transforming the train set

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()# i want to apply model
